# %%
def generate_f(n, o, q):
    '''
    generates a random quadratic equation over F_q in n variables.
    q has to be odd.
    '''
    F = GF(q)
    # define the polynomial ring where the variables live
    R = PolynomialRing(F, n, 't')
    # construct a quadratic polynomial over F_q, such that every term has a vinegar variable
    f_k = sum(R.gens()[i]*sum(F.random_element()*R.gens()[j] for j in range(n)) for i in range(o, n)) 
    print(type(f_k))
    # print(f_k.coefficients())
    size = len(R.gens())
    gram = Matrix(F, size, size)
    for i in range(size):
        quadratic_terms = {R.gens()[i]: 2}
        gram[i, i] = f_k.coefficient(quadratic_terms)
        for j in range(i+1, n):
            other_terms = {R.gens()[i]: 1, R.gens()[j]: 1}
            gram[i, j] = f_k.coefficient(other_terms)
    print(gram)
    

    # Q = QuadraticForm(f_k);
    # # gets matrix of polar form
    # gram = Q.matrix() * F(2)**(-1);
    
    # further checks
    x = vector(R.gens())
    assert (x * gram * x == f_k)
    return gram

generate_f(8, 4, 9)
# Out:
# <class 'sage.rings.polynomial.multi_polynomial_libsingular.MPolynomial_libsingular'>
# [2, 1, 2, z2 + 2, 2, z2, 2, 2*z2, z2 + 2, z2 + 2, 2*z2, z2 + 1, z2 + 2, z2 + 2, 1, 2, z2 + 2, 1, z2 + 1, z2 + 2, 2*z2 + 1, 2*z2 + 1, z2 + 2]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 35
#      32     assert (x * gram * x == f_k)
#      33     return gram
# ---> 35 generate_f(Integer(8), Integer(4), Integer(9))
#
# Cell In[18], line 20, in generate_f(n, o, q)
#      18     for j in range(i+Integer(1), n):
#      19         other_terms = {R.gens()[i]: Integer(1), R.gens()[j]: Integer(1)}
# ---> 20         gram[i, j] = f_k.coefficient(other_terms)
#      21 print(gram)
#      24 Q = QuadraticForm(f_k);
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/matrix/matrix0.pyx:1508, in sage.matrix.matrix0.Matrix.__setitem__ (build/cythonized/sage/matrix/matrix0.c:15660)()
#    1506
#    1507         if single_row and single_col and not no_col_index:
# -> 1508             self.set_unsafe(row, col, self._coerce_element(value))
#    1509             return
#    1510
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/matrix/matrix0.pyx:1609, in sage.matrix.matrix0.Matrix._coerce_element (build/cythonized/sage/matrix/matrix0.c:17163)()
#    1607     if isinstance(x, Element) and (<Element> x)._parent is self._base_ring:
#    1608         return x
# -> 1609     return self._base_ring(x)
#    1610
#    1611 ###########################################################
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/structure/parent.pyx:900, in sage.structure.parent.Parent.__call__ (build/cythonized/sage/structure/parent.c:13639)()
#     898 if mor is not None:
#     899     if no_extra_args:
# --> 900         return mor._call_(x)
#     901     else:
#     902         return mor._call_with_args(x, args, kwds)
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/structure/coerce_maps.pyx:293, in sage.structure.coerce_maps.NamedConvertMap._call_ (build/cythonized/sage/structure/coerce_maps.c:8877)()
#     291     raise TypeError(f"cannot coerce {x} to {C}")
#     292 cdef Map m
# --> 293 cdef Element e = method(C)
#     294 if e is None:
#     295     raise RuntimeError("BUG in coercion model: {} method of {} returned None".format(self.method_name, type(x)))
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/rings/polynomial/multi_polynomial.pyx:114, in sage.rings.polynomial.multi_polynomial.MPolynomial._scalar_conversion (build/cythonized/sage/rings/polynomial/multi_polynomial.c:9580)()
#     112 """
#     113 if self.degree() <= 0:
# --> 114     return R(self.constant_coefficient())
#     115 raise TypeError(f"unable to convert non-constant polynomial {self} to {R}")
#     116
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/structure/parent.pyx:900, in sage.structure.parent.Parent.__call__ (build/cythonized/sage/structure/parent.c:13639)()
#     898 if mor is not None:
#     899     if no_extra_args:
# --> 900         return mor._call_(x)
#     901     else:
#     902         return mor._call_with_args(x, args, kwds)
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/structure/coerce_maps.pyx:293, in sage.structure.coerce_maps.NamedConvertMap._call_ (build/cythonized/sage/structure/coerce_maps.c:8877)()
#     291     raise TypeError(f"cannot coerce {x} to {C}")
#     292 cdef Map m
# --> 293 cdef Element e = method(C)
#     294 if e is None:
#     295     raise RuntimeError("BUG in coercion model: {} method of {} returned None".format(self.method_name, type(x)))
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/rings/finite_rings/element_givaro.pyx:1378, in sage.rings.finite_rings.element_givaro.FiniteField_givaroElement._integer_ (build/cythonized/sage/rings/finite_rings/element_givaro.cpp:20902)()
#    1376     if a < self._cache.objectptr.characteristic():
#    1377         return Integer(a)
# -> 1378     raise TypeError("not in prime subfield")
#    1379
#    1380 def _log_to_int(FiniteField_givaroElement self):
#
# TypeError: not in prime subfield

# %%
def KeyGen(n, m, o, q):
    '''
    returns a tuple (pk, sk) containing the public key and the secret key.
    The secret is again a tuple (FF, M), where 
            - FF is the central map and 
            - M an invertible linear transformation.
    '''
    F = GF(q)
    FF = []
    # pick the quadratic equations at random
    for i in range(m):
        FF.append(generate_f(n, o, q))
    # print("FF[2] \n", FF[2])
    # choose an invertible linear transform F_n -> F_n 
    M = GL(n, F).random_element().matrix()
    sk = (FF, M)
    # construct the public key
    PP = []
    for i in range(len(FF)):
        PP.append(M.transpose()*FF[i]*M)
    # print("PP[2] \n", PP[2])
    pk = PP
    return pk, sk

# %%
def solve_FF(n, m, o, q, sk, t, F, R, x):
    # pick random values for the 'vinegar' variables
    for i in range(n-o):
        # print(i+o-1)
        x[i+o] = F.random_element()
    # print(x)
    # solve the system F(s') = t (m linear equations in o variables, m <= o)
    FF, M = sk
    system = [x*FF[i]*x - t[i] for i in range(m)]
    A = matrix([ [eq.coefficient(v) for v in x[0:o]] for eq in system])
    # TODO try with and without max
    b = vector([-eq.constant_coefficient() for eq in system])
    # print("het rechterlid", b)
    sol = A.solve_right(b)
    return sol

# %%
def sign(n, m, o, q, sk, t):
    
    '''
    returns the UOV signature as a vector of length n
    '''
    assert (len(t) == m)
    F = GF(q)
    R = PolynomialRing(F, n, 'x')
    x = vector(R.gens())
    
    # we skip the hashing part
    i = 1
    while true:
        try:
            sol_temp = solve_FF(n, m, o, q, sk, t, F, R, x)
            # print("sol", sol_temp)
            break
        except ValueError:
            i+=1
            print(f'Hélas ... Too much vinegar. Poging {i}')
    # print("de inverse transformatie", sk[1].inverse())
    # print('element', sol_temp[2])
    # create s'
    sol = [sol_temp[i] for i in range(o)]
    sol.extend([x[i] for i in range(o, n)])
    assert (len(sol) == n)
    # print(sol)
    signature = sk[1].inverse()*vector(sol)
    return signature

# %%
def verify(n, m, o, q, PP, signature):
    F = GF(q)
    R = PolynomialRing(F, n, 'x')
    x = vector(R.gens())
    t_bar = []
    for i in range(len(PP)):
        t_bar.append(signature*PP[i]*signature)
    return t_bar

# %%
# testsetup
n, m, o, q = 8, 4, 4, 9
kg = KeyGen(n, m, o, q)
pk, sk = kg[0], kg[1]
t = [GF(q).random_element() for i in range(m)]
s = sign(n, m, o, q, sk, t)
v = verify(n, m, o, q, pk, s)
# TEST
print('te ondertekenen:', t)
print('response:', v)
# Out:
# te ondertekenen: [z2, 2*z2, 2, 2*z2 + 2]
# response: [z2, (-z2), -1, (-z2 - 1)]
