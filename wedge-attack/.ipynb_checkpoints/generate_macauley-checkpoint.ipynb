# %%
def generate_M(p, d):
    """
    input: (p) a system of homogeneous quadratic equations, (d) the desired degree of the output matrix
    returns a macauley matrix of degree d, with (n d) columns and m(n d-2) rows
    """
    pass
